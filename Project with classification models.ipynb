# %% [markdown]
# ## Importing packages

# %%
import pandas as pd

# %% [markdown]
# ## Importing datasets

# %%
Absenteeism = pd.read_csv("Absenteeism_at_work_train.csv")
Absenteeism.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time Age  \
# 0                     289                               36            13  33
# 1                     118                               13            18  50
# 2                     179                               51            18  38
# 3                     279                                5            14  39
# 4                     289                               36            13  33
#
#   Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %% [markdown]
# ## Dataset description

# %%
Absenteeism.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  666.000000          666.000000        666.000000       666.000000
# mean    17.674174           19.469970          6.441441         3.893393
# std     11.075428            8.345175          3.573128         1.423451
# min      1.000000            0.000000          1.000000         2.000000
# 25%      7.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          7.000000         4.000000
# 75%     28.000000           26.000000         10.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  666.000000              666.000000                       666.000000
# mean     2.552553              222.818318                        30.370871
# std      1.134994               66.853234                        14.905486
# ...

# %% [markdown]
# ## Data cleaning

# %%
Absenteeism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 666 entries, 0 to 665
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               666 non-null    int64
#  1   Reason for absence               666 non-null    int64
#  2   Month of absence                 666 non-null    int64
#  3   Day of the week                  666 non-null    int64
#  4   Seasons                          666 non-null    int64
#  5   Transportation expense           666 non-null    int64
#  6   Distance from Residence to Work  666 non-null    int64
#  7   Service time                     666 non-null    int64
#  8   Age                              666 non-null    object
#  9   Work load Average/day            666 non-null    object
#  10  Hit target                       665 non-null    float64
#  11  Disciplinary failure             666 non-null    int64
# ...

# %% [markdown]
# ###  From the above metadata we observed that two features Age and Work load Average/day are string data types which should be actually numeric data type

# %%
Absenteeism.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         1
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             2
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %% [markdown]
# ### Work load Average/day had a blank space in its name and the values were comma separated. So, we had to clean up all the blank spaces in the column name and get rid of the comas in the data.

# %%
Absenteeism.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
Absenteeism.columns = [x.strip(' ') for x in Absenteeism.columns]

# %%
Absenteeism.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
Absenteeism.Age = pd.to_numeric(Absenteeism.Age, errors = 'coerce')

# %%
Absenteeism.Age.describe()
# Out:
# count    665.000000
# mean      36.351880
# std        6.515928
# min        0.000000
# 25%       31.000000
# 50%       37.000000
# 75%       40.000000
# max       58.000000
# Name: Age, dtype: float64

# %%
Absenteeism[Absenteeism['Age']==0]
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 200  23                  19                 4                4        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 200                     378                               49            11
#
#      Age Work load Average/day  ...  Disciplinary failure  Education  Son  \
# 200  0.0               326,452  ...                     0          1    2
#
#      Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 200               0              1    4    65.0     174               21
#
#      Absenteeism time in hours
# 200                          8
#
# [1 rows x 21 columns]

# %%
Absenteeism['Work load Average/day'].value_counts()
# Out:
# 222,196    35
# 264,249    33
# 343,253    29
# 265,017    28
# 284,853    25
# 308,593    24
# 268,519    23
# 244,387    22
# 241,476    22
# 284,031    22
# 205,917    21
# 251,818    21
# 326,452    20
# 230,290    20
# 253,957    19
# 236,629    19
# 294,217    19
# 239,554    19
# 253,465    18
# 265,615    18
# 306,345    18
# 302,585    18
# 378,884    16
# 275,312    16
# 377,550    16
# 246,074    16
# 249,797    15
# 280,549    15
# 261,306    15
# 313,532    14
# 239,409    13
# 246,288    12
# 261,756    12
# 330,061    11
# 12          1
# 0           1
# Name: Work load Average/day, dtype: int64

# %%
Absenteeism['Work load Average/day'] = Absenteeism['Work load Average/day'].str.replace(',','')

# %%
Absenteeism['Work load Average/day'] = pd.to_numeric(Absenteeism['Work load Average/day'], errors = 'coerce')
Absenteeism['Work load Average/day'].describe()
# Out:
# count       666.000000
# mean     272636.885886
# std       42957.873835
# min           0.000000
# 25%      244387.000000
# 50%      264249.000000
# 75%      294217.000000
# max      378884.000000
# Name: Work load Average/day, dtype: float64

# %% [markdown]
# ###  We also performed null value checks and valid value checks wherever applicable. We dropped all the observations which had invalid value

# %%
f = (Absenteeism['Age'].isnull()) | (Absenteeism['Age']==0)
Absenteeism = Absenteeism[~f]

# %%
f2 = (Absenteeism['Weight'].isnull()) | (Absenteeism['Weight']==0)
Absenteeism = Absenteeism[~f2]

# %%
f3 = Absenteeism['Hit target'].isnull()
Absenteeism = Absenteeism[~f3]

# %%
f4 = (Absenteeism['Work load Average/day'].isnull()) | (Absenteeism['Work load Average/day']==0)
Absenteeism = Absenteeism[~f4]

# %%
Absenteeism['Seasons'].value_counts()
# Out:
# 4    194
# 2    188
# 1    150
# 3    128
# Name: Seasons, dtype: int64

# %%
Absenteeism['Day of the week'].value_counts()
# Out:
# 2    147
# 3    143
# 4    133
# 6    127
# 5    110
# Name: Day of the week, dtype: int64

# %%
Absenteeism['ID'].value_counts()
# Out:
# 3     111
# 28     70
# 34     46
# 20     42
# 11     39
# 22     34
# 15     33
# 24     30
# 36     28
# 14     25
# 33     24
# 10     22
# 1      21
# 5      17
# 17     17
# 18     15
# 13     14
# 30      7
# 6       7
# 27      7
# 25      6
# 7       6
# 9       6
# 2       5
# 23      5
# 26      4
# 32      4
# 31      3
# 19      3
# 12      3
# 21      2
# 29      2
# 8       1
# 16      1
# Name: ID, dtype: int64

# %%
Absenteeism['Reason for absence'].value_counts()
# Out:
# 23    144
# 28    105
# 27     59
# 13     50
# 0      36
# 19     31
# 26     30
# 22     29
# 25     29
# 11     24
# 18     21
# 10     17
# 1      16
# 14     16
# 7      13
# 12      8
# 21      6
# 6       5
# 8       4
# 9       4
# 24      3
# 5       2
# 4       2
# 15      2
# 16      1
# 3       1
# 2       1
# 17      1
# Name: Reason for absence, dtype: int64

# %%
Absenteeism['Social drinker'].value_counts()
# Out:
# 1    387
# 0    273
# Name: Social drinker, dtype: int64

# %%
Absenteeism['Social smoker'].value_counts()
# Out:
# 0    615
# 1     45
# Name: Social smoker, dtype: int64

# %%
Absenteeism['Disciplinary failure'].value_counts()
# Out:
# 0    624
# 1     36
# Name: Disciplinary failure, dtype: int64

# %%
features = Absenteeism.drop(['Absenteeism time in hours','ID'], axis=1)

# %%
features.corr()
# Out:
#                                  Reason for absence  Month of absence  \
# Reason for absence                         1.000000         -0.111750
# Month of absence                          -0.111750          1.000000
# Day of the week                            0.099010          0.005747
# Seasons                                   -0.135580          0.438276
# Transportation expense                    -0.138688          0.136937
# Distance from Residence to Work            0.161369         -0.009679
# Service time                               0.073491         -0.059274
# Age                                       -0.044847          0.012262
# Work load Average/day                     -0.142392         -0.173795
# Hit target                                 0.120739         -0.465294
# Disciplinary failure                      -0.559742          0.113275
# Education                                 -0.084129         -0.055775
# ...

# %% [markdown]
# ###  We plotted the collinearity between all the variables and dropped the features with an absolute correlated coefficient value of above 0.8. Body Mass Index seem to be highly correlated with other features and it was dropped.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize= (10, 10))
sns.heatmap(features.corr())
# Out:
# <AxesSubplot:>

# %%
import numpy as np

# Create correlation matrix
corr_matrix = features.corr().abs()

# Select upper triangle of correlation matrix 
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool)) 

# Find index of feature columns with correlation greater than 0.8 
to_drop = [column for column in upper.columns if any(upper[column] > 0.8)] 

new_features = features.drop(to_drop, axis=1)

# %%
new_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 0 to 665
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Reason for absence               660 non-null    int64
#  1   Month of absence                 660 non-null    int64
#  2   Day of the week                  660 non-null    int64
#  3   Seasons                          660 non-null    int64
#  4   Transportation expense           660 non-null    int64
#  5   Distance from Residence to Work  660 non-null    int64
#  6   Service time                     660 non-null    int64
#  7   Age                              660 non-null    float64
#  8   Work load Average/day            660 non-null    int64
#  9   Hit target                       660 non-null    float64
#  10  Disciplinary failure             660 non-null    int64
#  11  Education                        660 non-null    int64
# ...

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 660 entries, 0 to 665
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Reason for absence               660 non-null    int64
#  1   Month of absence                 660 non-null    int64
#  2   Day of the week                  660 non-null    int64
#  3   Seasons                          660 non-null    int64
#  4   Transportation expense           660 non-null    int64
#  5   Distance from Residence to Work  660 non-null    int64
#  6   Service time                     660 non-null    int64
#  7   Age                              660 non-null    float64
#  8   Work load Average/day            660 non-null    int64
#  9   Hit target                       660 non-null    float64
#  10  Disciplinary failure             660 non-null    int64
#  11  Education                        660 non-null    int64
# ...

# %% [markdown]
# ###   We also converted the target variable, Absenteeism time in hours, to categorical variable for our initial analysis. The following are the thresholds we used to convert our target variable to categorical variable.
#
#
# Target Value Threshold by Groups
#
# Group Number	Threshold
#
# 0	Number of hours=0
#
# 1	0 < Number of hours <= 6
#
# 2	Number of hours > 6

# %%
Absenteeism2 = Absenteeism
g1 = (Absenteeism2['Absenteeism time in hours']==0)
g2 = (Absenteeism2['Absenteeism time in hours']>0) & (Absenteeism2['Absenteeism time in hours']<=6)
g3 = (Absenteeism2['Absenteeism time in hours']>6)

# %%
Absenteeism2.loc[g1,'Absenteeism time in hours'] = 0
Absenteeism2.loc[g2,'Absenteeism time in hours'] = 1
Absenteeism2.loc[g3,'Absenteeism time in hours'] = 2

# %%
Absenteeism2['Absenteeism time in hours'].value_counts()
# Out:
# 1    383
# 2    240
# 0     37
# Name: Absenteeism time in hours, dtype: int64

# %%
target = Absenteeism2['Absenteeism time in hours']

# %% [markdown]
# ##  Data splitting

# %%
# Splitting the model
from sklearn.model_selection import train_test_split
y = target
X = Absenteeism2.drop(['Absenteeism time in hours'],axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,
random_state=12345)

# %%
# Random forest technique
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
y_predict = clf.predict(X_test)
print(confusion_matrix(y_test, y_predict))
print("Accuracy of Random Forest Technique is:", accuracy_score(y_test, y_predict)*100)
# Out:
# [[ 8  1  0]
#  [ 0 69 11]
#  [ 0 11 32]]
# Accuracy of Random Forest Technique is: 82.57575757575758

# %%
# Decision Tree technique
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
dt_model = tree.DecisionTreeClassifier()
dt_model.fit(X_train, y_train)
y_predict = dt_model.predict(X_test)
print(confusion_matrix(y_test, y_predict))
print("Accuracy of Decision Tree Technique is:", accuracy_score(y_test, y_predict)*100)
# Out:
# [[ 8  1  0]
#  [ 0 69 11]
#  [ 0 17 26]]
# Accuracy of Decision Tree Technique is: 78.03030303030303

# %%
from sklearn.tree import export_graphviz

# export the decision tree to a tree.dot file
# for visualizing the plot easily anywhere
export_graphviz(dt_model, out_file ='tree.dot', feature_names =X.columns)

# %%
dot_data = tree.export_graphviz(dt_model, out_file=None,
                                feature_names=X.columns,
                                filled=True, rounded=True,
                                special_characters=True)

# %% [markdown]
# import graphviz as g
# from graphviz import Source
# graph = g.Source(dot_data)
# graph

# %%
# Naïve Bayes Classifiers
from sklearn.naive_bayes import GaussianNB 
gnb = GaussianNB() 
gnb = gnb.fit(X_train, y_train)
y_predict = gnb.predict(X_test)
print(confusion_matrix(y_test, y_predict))
print("Accuracy of Naive Bayes Classifiers is:", accuracy_score(y_test, y_predict)*100)
# Out:
# [[ 7  1  1]
#  [ 0 66 14]
#  [ 1 18 24]]
# Accuracy of Naive Bayes Classifiers is: 73.48484848484848

# %%
# Support Vector Machine
# Normalizing the data & training the Normalized data
from sklearn import preprocessing
y = target
X = Absenteeism2.drop(['Absenteeism time in hours'],axis=1)
Normalized_X = preprocessing.normalize(X)
X_train, X_test, y_train, y_test = train_test_split(Normalized_X, y, test_size=0.20,
random_state=12345)

# %%
# Design the model
from sklearn import svm
support = svm.SVC(kernel='linear')
support.fit(X_train, y_train)
y_predict = support.predict(X_test)
print(confusion_matrix(y_test, y_predict))
print("Accuracy of Support Vector Machine through linear kernel is:", accuracy_score(y_test, y_predict)*100)
# Out:
# [[ 0  9  0]
#  [ 0 80  0]
#  [ 0 43  0]]
# Accuracy of Support Vector Machine through linear kernel is: 60.60606060606061

# %%
#ROC curve on decision tree and random forest
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
y = target
rf_clf = RandomForestClassifier(max_depth= 5, n_estimators=60)
y_score = rf_clf.fit(X_train, y_train).predict_proba(X_test)
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])
n_classes = y_test_bin.shape[1]
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
color_dict = ['darkorange', 'lightseagreen', 'coral']
label_dict = ['Absenteeism time equals 0', 'Absenteeism time between 0 and 6', 'Absenteeism time morethan 6']

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    plt.plot(fpr[i], tpr[i], color=color_dict[i], lw=2, label =label_dict[i] )
    print('AUC for Class {}: {}'.format(i+1, auc(fpr[i], tpr[i])))
    
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curves with Random Forest')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
# Out:
# AUC for Class 1: 0.9448961156278229
# AUC for Class 2: 0.8265625000000001
# AUC for Class 3: 0.8166971518160439

# %%
#ROC curve on decision tree and random forest

y = target
tree_clf = tree.DecisionTreeClassifier()
y_score = tree_clf.fit(X_train, y_train).predict_proba(X_test)
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])
n_classes = y_test_bin.shape[1]
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
color_dict = ['darkorange', 'lightseagreen', 'coral']
label_dict = ['Absenteeism time equals 0', 'Absenteeism time between 0 and 6', 'Absenteeism time morethan 6']


for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_score[:, i])
    plt.plot(fpr[i], tpr[i], color=color_dict[i], lw=2, label =label_dict[i])
    print('AUC for Class {}: {}'.format(i+1, auc(fpr[i], tpr[i])))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curves with Decision Tree')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
# Out:
# AUC for Class 1: 0.9444444444444444
# AUC for Class 2: 0.7400240384615384
# AUC for Class 3: 0.7209302325581396
